# %% [markdown]
# ### Library Import

# %%
# Standard library
import os
import math
# Dataframe handling
import numpy as np
import pandas as pd
# Matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline
# Seaborn plots
import seaborn as sns
# Hide warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ![title](02_data_extra/nhanes_logo_image.jpg)

# %% [markdown]
# # 2 Explore & Check Data

# %% [markdown]
# ### Data Import

# %%
path_input = os.path.join('00_data_input')
path_output = os.path.join('03_data_output')
path_categ = os.path.join(path_output, 'nhanes_categ.csv')

# %%
df_categ = pd.read_csv(path_categ)
df_categ.head()
# Out:
#       id  CODE_status  CM_height  KG_weight  KG_M2_bmi  \
# 0  41475            3      154.7      138.9      58.04
# 1  41476            1      120.4       22.0      15.18
# 2  41477            1      167.1       83.9      30.05
# 3  41478            1        NaN       11.5        NaN
# 4  41479            1      154.4       65.7      27.56
#
#    CODE_bmi_category_youth  BINARY_gender  YEARS_age  CODE_race  \
# 0                      NaN              2         62          5
# 1                      NaN              2          6          5
# 2                      NaN              1         71          3
# 3                      NaN              2          1          3
# 4                      NaN              1         52          1
#
#    CODE_race_extended         ...           CAT2_age  CAT_bmi  LAB_bmi  \
# 0                 NaN         ...              60-69      4.0      40+
# 1                 NaN         ...              01-09     -1.0    10-18
# 2                 NaN         ...              70-79      2.0    30-35
# 3                 NaN         ...              01-09      NaN  unknown
# 4                 NaN         ...              50-59      1.0    25-30
#
#       STR_bmi  CAT1_race  CAT2_race  CAT_houshold_education  \
# 0      obese3   otherOld      other                     4.0
# 1  underweigt   otherOld      other                     5.0
# 2      obese1      white      white                     3.0
# 3     unknown      white      white                     2.0
# 4  overweight    mexican    mexican                     1.0
#
#    LAB_houshold_education  CAT_income_houshold  LAB_income_houshold
# 0               AA-Degree                  6.0             025-035K
# 1                College+                 12.0                100+K
# 2              Highschool                  5.0             020-025K
# 3             <12th-Grade                  3.0             010-015K
# 4              <9th-Grade                  8.0             045-055K
#
# [5 rows x 38 columns]

# %%
sns.set(style="ticks", palette="pastel")
fig, ax = plt.subplots(figsize=(20,15))
sns.boxplot(x='CAT2_race', y='KG_M2_bmi', hue='year', data=df_categ, palette=['m', 'g', 'b', 'r', 'y'], ax=ax)
sns.despine(offset=10, trim=True)

# %%
import seaborn as sns
sns.set(style="white")

df = sns.load_dataset("iris")

g = sns.PairGrid(df, diag_sharey=False)
g.map_lower(sns.kdeplot)
g.map_upper(sns.scatterplot)
g.map_diag(sns.kdeplot, lw=3)

# %%
sns.lmplot(x='CM_height', y='KG_weight', hue='BINARY_gender', data=df_categ,
           size=8, markers='+', scatter_kws={'s': 2})
